# %%
import pandas as pd
import numpy as np

# %%
vine = "C:/Users/Perry/Documents/GitHub/Amazon_Vine_Analysis/vine_table.csv"
vine_df = pd.read_csv(vine, encoding='latin1', names = ["review_id", "star_rating", "helpful_votes", "total_votes", "vine", "verified_purchase"])
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vine_df['vine'].value_counts()
# Out:
# N     2633399
# Y       10215
# \N          5
# Name: vine, dtype: int64

# %%
low_memory = False

# %%
vine_df.head()
# Out:
#         review_id star_rating helpful_votes total_votes vine verified_purchase
# 0   REAKC26P07MDN           5             0           0    N                 Y
# 1  R3NU7OMZ4HQIEG           2             0           1    N                 Y
# 2  R14QJW3XF8QO1P           5             0           0    N                 Y
# 3  R2HB7AX0394ZGY           5             0           0    N                 Y
# 4   RGKMPDQGSAHR3           5             0           0    N                 Y

# %%
len(vine_df)
# Out:
# 2643619

# %%
vine_df.dtypes
# Out:
# review_id            object
# star_rating          object
# helpful_votes        object
# total_votes          object
# vine                 object
# verified_purchase    object
# dtype: object

# %%
vine_df["star_rating"].dropna
# Out:
# <bound method Series.dropna of 0          5
# 1          2
# 2          5
# 3          5
# 4          5
#           ..
# 2643614    1
# 2643615    5
# 2643616    3
# 2643617    3
# 2643618    2
# Name: star_rating, Length: 2643619, dtype: object>

# %%
len(vine_df)
# Out:
# 2643619

# %%
vine_df["star_rating"].value_counts()
# Out:
# 5     1393801
# 4      329545
# 5      251752
# 1      212980
# 3      184589
# 2      129488
# 4       51735
# 1       35883
# 3       32046
# 2       21795
# \N          5
# Name: star_rating, dtype: int64

# %%
vine_df2 = vine_df[vine_df['star_rating']!='\\N']
vine_df2['star_rating'] = vine_df2['star_rating'].astype(float)
vine_df2
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               review_id  star_rating helpful_votes total_votes vine  \
# 0         REAKC26P07MDN          5.0             0           0    N
# 1        R3NU7OMZ4HQIEG          2.0             0           1    N
# 2        R14QJW3XF8QO1P          5.0             0           0    N
# 3        R2HB7AX0394ZGY          5.0             0           0    N
# 4         RGKMPDQGSAHR3          5.0             0           0    N
# ...                 ...          ...           ...         ...  ...
# 2643614   R40AVFLMGSX5Q          1.0            32          34    N
# ...

# %%
vine_df3 = vine_df[vine_df['helpful_votes']!='\\N']
vine_df3['helpful_votes'] = vine_df3['helpful_votes'].astype(float)
vine_df3
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               review_id star_rating  helpful_votes total_votes vine  \
# 0         REAKC26P07MDN           5            0.0           0    N
# 1        R3NU7OMZ4HQIEG           2            0.0           1    N
# 2        R14QJW3XF8QO1P           5            0.0           0    N
# 3        R2HB7AX0394ZGY           5            0.0           0    N
# 4         RGKMPDQGSAHR3           5            0.0           0    N
# ...                 ...         ...            ...         ...  ...
# 2643614   R40AVFLMGSX5Q           1           32.0          34    N
# ...

# %%
vine_df4 = vine_df[vine_df['total_votes']!='\\N']
vine_df4['total_votes'] = vine_df4['total_votes'].astype(float)
vine_df4
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               review_id star_rating helpful_votes  total_votes vine  \
# 0         REAKC26P07MDN           5             0          0.0    N
# 1        R3NU7OMZ4HQIEG           2             0          1.0    N
# 2        R14QJW3XF8QO1P           5             0          0.0    N
# 3        R2HB7AX0394ZGY           5             0          0.0    N
# 4         RGKMPDQGSAHR3           5             0          0.0    N
# ...                 ...         ...           ...          ...  ...
# 2643614   R40AVFLMGSX5Q           1            32         34.0    N
# ...

# %%
vine_df5 = vine_df[vine_df['vine']!='\\N']
vine_df5['vine'] = vine_df5['vine'].astype(bool)
vine_df5
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               review_id star_rating helpful_votes total_votes  vine  \
# 0         REAKC26P07MDN           5             0           0  True
# 1        R3NU7OMZ4HQIEG           2             0           1  True
# 2        R14QJW3XF8QO1P           5             0           0  True
# 3        R2HB7AX0394ZGY           5             0           0  True
# 4         RGKMPDQGSAHR3           5             0           0  True
# ...                 ...         ...           ...         ...   ...
# 2643614   R40AVFLMGSX5Q           1            32          34  True
# ...

# %%
vine_df_clean = vine_df[vine_df['verified_purchase']!='\\N']
vine_df_clean['total_votes'] = vine_df_clean['total_votes'].astype(float)
vine_df_clean['helpful_votes'] = vine_df_clean['helpful_votes'].astype(float)
vine_df_clean['star_rating'] = vine_df_clean['star_rating'].astype(float)
vine_df_clean['verified_purchase'] = vine_df_clean['verified_purchase'].apply(lambda x: True if x == 'Y' else False)
vine_df_clean['vine'] = vine_df_clean['vine'].apply(lambda x: True if x == 'Y' else False)
vine_df_clean
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
vine_df_clean['vine'].value_counts()
# Out:
# False    2633399
# True       10215
# Name: vine, dtype: int64

# %%
vine_df_clean[vine_df_clean['total_votes']>=20.0]
# Out:
#               review_id  star_rating  helpful_votes  total_votes   vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0  False
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0  False
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0  False
# 267       RVTYWID2TPMMY          2.0           35.0         42.0  False
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0  False
# ...                 ...          ...            ...          ...    ...
# 2643586   RDDVO19Y8YH01          1.0           12.0         56.0  False
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0  False
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0  False
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0  False
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0  False
#
#          verified_purchase
# 128                   True
# 161                   True
# ...

# %%
vine_df_clean_filtered_total_votes = vine_df_clean[vine_df_clean['total_votes']>=20.0]

# %%
vine_df_clean_filtered_total_votes.dtypes
# Out:
# review_id             object
# star_rating          float64
# helpful_votes        float64
# total_votes          float64
# vine                    bool
# verified_purchase       bool
# dtype: object

# %%
vine_df_clean_filtered_total_votes['ratio'] = vine_df_clean_filtered_total_votes['helpful_votes']/vine_df_clean_filtered_total_votes['total_votes']
vine_df_clean_filtered_total_votes[vine_df_clean_filtered_total_votes['ratio']>=0.5]
# Out:
# C:\Users\Perry\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#               review_id  star_rating  helpful_votes  total_votes   vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0  False
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0  False
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0  False
# 267       RVTYWID2TPMMY          2.0           35.0         42.0  False
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0  False
# ...                 ...          ...            ...          ...    ...
# ...

# %%
vine_df_clean_filtered_total_votes_ratio = vine_df_clean_filtered_total_votes[vine_df_clean_filtered_total_votes['ratio']>= 0.5]

# %%
vine_df_clean_filtered_total_votes_ratio
# Out:
#               review_id  star_rating  helpful_votes  total_votes   vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0  False
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0  False
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0  False
# 267       RVTYWID2TPMMY          2.0           35.0         42.0  False
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0  False
# ...                 ...          ...            ...          ...    ...
# 2643577  R37NBT4U1EL04K          5.0           47.0         61.0  False
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0  False
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0  False
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0  False
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0  False
#
#          verified_purchase     ratio
# 128                   True  0.870968
# ...

# %%
vine_df_clean_filtered_total_votes_ratio_paid = vine_df_clean_filtered_total_votes_ratio[vine_df_clean_filtered_total_votes_ratio['vine'] == True]
vine_df_clean_filtered_total_votes_ratio_paid
# Out:
#               review_id  star_rating  helpful_votes  total_votes  vine  \
# 8547     R3A71VR1JZD8WF          2.0           27.0         30.0  True
# 10246    R16OMUJIGI18JZ          5.0           72.0         72.0  True
# 25168    R3TS8ZP2FHQ9XR          5.0           39.0         42.0  True
# 46422    R2MHP919VZN7DI          5.0           29.0         30.0  True
# 66446     RD2BCTVS59A5L          2.0           20.0         20.0  True
# ...                 ...          ...            ...          ...   ...
# 2596353   RV5OQXGCYHSC6          5.0           24.0         28.0  True
# 2596519  R2XLAQL0E2UPWQ          4.0           33.0         34.0  True
# 2597336  R2UJFVH97OJORD          3.0          106.0        117.0  True
# 2597830   RJXG84I331N9T          3.0          146.0        154.0  True
# 2598196   RNGRV0353CDWX          4.0          109.0        115.0  True
#
#          verified_purchase     ratio
# 8547                 False  0.900000
# 10246                False  1.000000
# ...

# %%
vine_df_clean_filtered_total_votes_ratio_unpaid = vine_df_clean_filtered_total_votes_ratio[vine_df_clean_filtered_total_votes_ratio['vine'] == False]
vine_df_clean_filtered_total_votes_ratio_unpaid
# Out:
#               review_id  star_rating  helpful_votes  total_votes   vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0  False
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0  False
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0  False
# 267       RVTYWID2TPMMY          2.0           35.0         42.0  False
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0  False
# ...                 ...          ...            ...          ...    ...
# 2643577  R37NBT4U1EL04K          5.0           47.0         61.0  False
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0  False
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0  False
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0  False
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0  False
#
#          verified_purchase     ratio
# 128                   True  0.870968
# ...

# %%
total_paid = len(vine_df_clean_filtered_total_votes_ratio_paid)
total_paid
# Out:
# 170

# %%
total_unpaid = len(vine_df_clean_filtered_total_votes_ratio_unpaid)
total_unpaid
# Out:
# 37840

# %%
total_paid_5_star_df = vine_df_clean_filtered_total_votes_ratio_paid[vine_df_clean_filtered_total_votes_ratio_paid['star_rating'] == 5]
total_paid_5_star_df
total_paid_5_star = len(total_paid_5_star_df)
total_paid_5_star
# Out:
# 65

# %%
total_unpaid_5_star_df = vine_df_clean_filtered_total_votes_ratio_unpaid[vine_df_clean_filtered_total_votes_ratio_unpaid['star_rating'] == 5]
total_unpaid_5_star_df
total_unpaid_5_star = len(total_unpaid_5_star_df)
total_unpaid_5_star
# Out:
# 20612

# %%
percent_5_star_paid = len(total_paid_5_star_df)/len(vine_df_clean_filtered_total_votes_ratio_paid)
percent_5_star_paid
# Out:
# 0.38235294117647056

# %%
percent_5_star_unpaid = len(total_unpaid_5_star_df)/len(vine_df_clean_filtered_total_votes_ratio_unpaid)
percent_5_star_unpaid
# Out:
# 0.5447145877378435
